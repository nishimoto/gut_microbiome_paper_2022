# %%
import pandas as pd
pd.set_option('display.max_rows', 50)

# %%
# https://github.com/WittmannF/sort-google-scholar
# !git clone https://github.com/WittmannF/sort-google-scholar.git
# Out:
# Cloning into 'sort-google-scholar'...
# remote: Enumerating objects: 244, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 244 (delta 3), reused 6 (delta 2), pack-reused 232
# Receiving objects: 100% (244/244), 137.39 KiB | 3.92 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
cd sort-google-scholar/
# Out:
# /content/sort-google-scholar

# %%
# !python sortgs.py --kw "gut microbiome" --sortby "cit/year"
# Out:
# Loading next 10 results
# Loading next 20 results
# Loading next 30 results
# Loading next 40 results
# Loading next 50 results
# Loading next 60 results
# Loading next 70 results
# Loading next 80 results
# Loading next 90 results
# Loading next 100 results
#                                                 Author  ... cit/year
# Rank                                                    ...
# 9        David, CF Maurice, RN Carmody, DB Gootenberg…  ...      899
# 87          Turnbaugh, RE Ley, MA Mahowald, V Magrini…  ...      712
# 8             Yatsunenko, FE Rey, MJ Manary, I Trehan…  ...      633
# 57     Turnbaugh, M Hamady, T Yatsunenko, BL Cantarel…  ...      588
# 3         Arumugam, J Raes, E Pelletier, D Le Paslier…  ...      571
# ...                                                ...  ...      ...
# 19                                               Brody  ...       10
# 78        Arumugam, J Raes, E Pelletier, D Le Paslier…  ...        9
# ...

# %%
# !mkdir -p data_output/result_2022

# %%
# !python sortgs.py --kw "gut microbiome" --sortby "cit/year" --startyear 2022 --csvpath data_output/result_2022
# Out:
# Loading next 10 results
# Loading next 20 results
# Loading next 30 results
# Loading next 40 results
# Loading next 50 results
# Loading next 60 results
# Loading next 70 results
# Loading next 80 results
# Loading next 90 results
# Loading next 100 results
#                                              Author  ... cit/year
# Rank                                                 ...
# 12               de Vos, H Tilg, M Van Hul, PD Cani  ...      150
# 4      Gacesa, A Kurilshikov, A Vich Vila, T Sinha…  ...       63
# 86    Zhang, Y Wan, T Zuo, YK Yeoh, Q Liu, L Zhang…  ...       63
# 2                                  Vijay, AM Valdes  ...       51
# 6               Lee, AM Thomas, LA Bolte, JR Björk…  ...       49
# ...                                             ...  ...      ...
# 24        Bi, L Feng, J He, C Liu, Y Wang, H Jiang…  ...        1
# 88                Koblinsky, KA Power, L Middleton…  ...        1
# 27                                  Wilmes, C Marti  ...        1
# ...

# %%
df = pd.read_csv('gut_microbiome.csv') # OBS: Update the file name

# %%
df.head(50)
# Out:
#     Rank                                             Author  \
# 0      9      David, CF Maurice, RN Carmody, DB Gootenberg…
# 1     87         Turnbaugh, RE Ley, MA Mahowald, V Magrini…
# 2      8           Yatsunenko, FE Rey, MJ Manary, I Trehan…
# 3     57    Turnbaugh, M Hamady, T Yatsunenko, BL Cantarel…
# 4      3       Arumugam, J Raes, E Pelletier, D Le Paslier…
# 5     60         Bäckhed, J Roswall, Y Peng, Q Feng, H Jia…
# 6     93   Gill, M Pop, RT DeBoy, PB Eckburg, PJ Turnbaugh…
# 7      7   Goodrich, JL Waters, AC Poole, JL Sutter, O K...
# 8     12                        Falony, M Joossens, S Vieir
# 9     10   Kau, PP Ahern, NW Griffin, AL Goodman, JI Gordon
# 10    96                                  Franzosa, A Sirot
# 11     5                                               Cani
# 12    35                             Vogt, RL Kerby, KA Dil
# 13     1                         Shreiner, JY Kao, VB Young
# 14    14         Cryan, KJ O'Riordan, K Sandhu, V Peterson…
# ...

# %%
df = pd.read_csv('data_output/result_2022/gut_microbiome.csv') # OBS: Update the file name

# %%
df
# Out:
#     Rank                                         Author  \
# 0     12             de Vos, H Tilg, M Van Hul, PD Cani
# 1      4   Gacesa, A Kurilshikov, A Vich Vila, T Sinha…
# 2     86  Zhang, Y Wan, T Zuo, YK Yeoh, Q Liu, L Zhang…
# 3      2                               Vijay, AM Valdes
# 4      6            Lee, AM Thomas, LA Bolte, JR Björk…
# ..   ...                                            ...
# 95    24      Bi, L Feng, J He, C Liu, Y Wang, H Jiang…
# 96    88              Koblinsky, KA Power, L Middleton…
# 97    27                                Wilmes, C Marti
# 98    40                 Grenda, E Iwan, I Chmielewska…
# 99    82                       P Guimaraes, J De Jonge…
#
#                                                 Title  Citations  Year  \
# 0     Gut microbiome and health: Mechanistic insights        150  2022
# 1   Environmental factors shaping the gut microbio...         63  2022
# 2   Prolonged impairment of short-chain fatty acid...         63  2022
# ...
